# %% [markdown]
# ## Convert address to lat/lng

# %%
import pandas as pd
import requests
from tqdm.auto import tqdm
tqdm.pandas()
# Out:
# /Users/ilenapeng/.pyenv/versions/3.9.7/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df = pd.read_csv('05-address.csv')
df.head()
# Out:
#                    school  count               circuit  \
# 0      Harvard University     24  District of Columbia
# 1         Yale University     16  District of Columbia
# 2     Stanford University     14  District of Columbia
# 3         Duke University     11  District of Columbia
# 4  University of Virginia      9  District of Columbia
#
#                                              address
# 0            Massachusetts Hall, Cambridge, MA 02138
# 1               105 Wall Street, New Haven, CT 06520
# 2            450 Serra Mall, Stanford, CA 94305-2061
# 3                   207 Allen Bldg, Durham, NC 27708
# 4  1827 University Avenue, Charlottesville, VA 22904

# %%
API_KEY = ''

# %%
def geocode(address):

    params = {
        'q': address,
        'apikey': API_KEY
    }

    response = requests.get('https://geocode.search.hereapi.com/v1/geocode', params=params)
    data = response.json()
    if len(data['items']) > 0:
        match = data['items'][0]
        # Create a dictionary of everything important
        result = {
            'lat': match['position']['lat'],
            'lng': match['position']['lng']
        }
        return pd.Series(result)

# use tqdm to get the time
geocoded = df.address.progress_apply(geocode)

geocoded.head()
# Out:
#   0%|          | 0/591 [00:00<?, ?it/s]
#         lat        lng
# 0  42.37717  -71.13507
# 1  41.31115  -72.92677
# 2  37.42765 -122.17006
# 3  35.99981  -78.94058
# 4  38.03662  -78.50258

# %%
# Combine dataframes
df_merge = pd.concat([df, geocoded], axis=1)
df_merge.head()
# Out:
#                    school  count               circuit  \
# 0      Harvard University     24  District of Columbia
# 1         Yale University     16  District of Columbia
# 2     Stanford University     14  District of Columbia
# 3         Duke University     11  District of Columbia
# 4  University of Virginia      9  District of Columbia
#
#                                              address       lat        lng
# 0            Massachusetts Hall, Cambridge, MA 02138  42.37717  -71.13507
# 1               105 Wall Street, New Haven, CT 06520  41.31115  -72.92677
# 2            450 Serra Mall, Stanford, CA 94305-2061  37.42765 -122.17006
# 3                   207 Allen Bldg, Durham, NC 27708  35.99981  -78.94058
# 4  1827 University Avenue, Charlottesville, VA 22904  38.03662  -78.50258

# %%
# Check the nulls -- should only be international schools
df_merge[df_merge.isnull().any(axis=1)]
# Out:
#                                                 school  count  \
# 17                                University of Oxford      2
# 29                      Heidelberg University, Germany      1
# 72                      Heidelberg University, Germany      1
# 140                            University of Cambridge      3
# 196                            University of Cambridge      3
# 235                               University of Oxford      6
# 253  University of Puerto Rico School of Public Adm...      1
# 309                               University of Oxford      4
# 373                      European University Institute      4
# 377                            University of Cambridge      3
# 386                               University of Oxford      2
# 516                               University of Oxford      2
# 585                               University of Oxford      1
#
#                   circuit address      lat     lng
# 17   District of Columbia     NaN  6.48812  2.6138
# 29   District of Columbia     NaN  6.48812  2.6138
# 72                 Eighth     NaN  6.48812  2.6138
# 140               Federal     NaN  6.48812  2.6138
# 196                 Fifth     NaN  6.48812  2.6138
# 235                 First     NaN  6.48812  2.6138
# 253                 First     NaN  6.48812  2.6138
# 309                 Ninth     NaN  6.48812  2.6138
# 373                Second     NaN  6.48812  2.6138
# 377                Second     NaN  6.48812  2.6138
# 386                Second     NaN  6.48812  2.6138
# 516                 Tenth     NaN  6.48812  2.6138
# 585                 Third     NaN  6.48812  2.6138

# %%
# Replace the NaN lat/lng values with actual NaNs
df_merge['lat'].replace(6.48812, np.nan, inplace=True)
df_merge['lng'].replace(2.6138, np.nan, inplace=True)

# %%
# Remove NAs so they don't show up in the final map
df_merge = df_merge.dropna()
# df_merge[df_merge.isnull().any(axis=1)]

# %%
# Save file
df_merge.to_csv('06-geocode.csv', index=False)
